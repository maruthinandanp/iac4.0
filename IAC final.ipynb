# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline 

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
data = pd.read_csv('D:\\UTD\\2019SP\\IAC final\\SDG_Indicators (1).csv')

# %%
data.head().T
# Out:
#                                                                                      0  \
# Goal                                                                                 1
# Target                                                                             1.1
# Indicator                                                                        1.1.1
# SeriesCode                                                                 SI_POV_DAY1
# SeriesDescription                    Proportion of population below international p...
# GeoAreaCode                                                                          1
# GeoAreaName                                                                      World
# TimePeriod                                                                        2002
# Value                                                                             25.6
# Time_Detail                                                                       2002
# ...

# %%
goal1 = data[data['Goal']==1]
goal1
# Out:
#        Goal Target Indicator   SeriesCode  \
# 0         1    1.1     1.1.1  SI_POV_DAY1
# 1         1    1.1     1.1.1  SI_POV_DAY1
# 2         1    1.1     1.1.1  SI_POV_DAY1
# 3         1    1.1     1.1.1  SI_POV_DAY1
# 4         1    1.1     1.1.1  SI_POV_DAY1
# 5         1    1.1     1.1.1  SI_POV_DAY1
# 6         1    1.1     1.1.1  SI_POV_DAY1
# 7         1    1.1     1.1.1  SI_POV_DAY1
# 8         1    1.1     1.1.1  SI_POV_DAY1
# 9         1    1.1     1.1.1  SI_POV_DAY1
# 10        1    1.1     1.1.1  SI_POV_DAY1
# 11        1    1.1     1.1.1  SI_POV_DAY1
# 12        1    1.1     1.1.1  SI_POV_DAY1
# 13        1    1.1     1.1.1  SI_POV_DAY1
# 14        1    1.1     1.1.1  SI_POV_DAY1
# 15        1    1.1     1.1.1  SI_POV_DAY1
# 16        1    1.1     1.1.1  SI_POV_DAY1
# 17        1    1.1     1.1.1  SI_POV_DAY1
# 18        1    1.1     1.1.1  SI_POV_DAY1
# 19        1    1.1     1.1.1  SI_POV_DAY1
# 20        1    1.1     1.1.1  SI_POV_DAY1
# ...

# %%
goal2 = data[data['Goal']==2]
goal2
# Out:
#         Goal Target Indicator     SeriesCode  \
# 64468      2    2.1     2.1.2  AG_PRD_FIESSI
# 64469      2    2.1     2.1.2  AG_PRD_FIESSI
# 64470      2    2.1     2.1.2  AG_PRD_FIESSI
# 64471      2    2.1     2.1.2  AG_PRD_FIESSI
# 64472      2    2.1     2.1.2  AG_PRD_FIESSI
# 64473      2    2.1     2.1.2  AG_PRD_FIESSI
# 64474      2    2.1     2.1.2  AG_PRD_FIESSI
# 64475      2    2.1     2.1.2  AG_PRD_FIESSI
# 64476      2    2.1     2.1.2  AG_PRD_FIESSI
# 64477      2    2.1     2.1.2  AG_PRD_FIESSI
# 64478      2    2.1     2.1.2  AG_PRD_FIESSI
# 64479      2    2.1     2.1.2  AG_PRD_FIESSI
# 64480      2    2.1     2.1.2  AG_PRD_FIESSI
# 64481      2    2.1     2.1.2  AG_PRD_FIESSI
# 64482      2    2.1     2.1.2  AG_PRD_FIESSI
# 64483      2    2.1     2.1.2  AG_PRD_FIESSI
# 64484      2    2.1     2.1.2  AG_PRD_FIESSI
# 64485      2    2.1     2.1.2  AG_PRD_FIESSI
# 64486      2    2.1     2.1.2  AG_PRD_FIESSI
# 64487      2    2.1     2.1.2  AG_PRD_FIESSI
# ...

# %%
goal3 = data[data['Goal']==3]
goal3
# Out:
#         Goal Target Indicator   SeriesCode  \
# 126848     3    3.1     3.1.2  SH_STA_BRTC
# 126849     3    3.1     3.1.2  SH_STA_BRTC
# 126850     3    3.1     3.1.2  SH_STA_BRTC
# 126851     3    3.1     3.1.2  SH_STA_BRTC
# 126852     3    3.1     3.1.2  SH_STA_BRTC
# 126853     3    3.1     3.1.2  SH_STA_BRTC
# 126854     3    3.1     3.1.2  SH_STA_BRTC
# 126855     3    3.1     3.1.2  SH_STA_BRTC
# 126856     3    3.1     3.1.2  SH_STA_BRTC
# 126857     3    3.1     3.1.2  SH_STA_BRTC
# 126858     3    3.1     3.1.2  SH_STA_BRTC
# 126859     3    3.1     3.1.2  SH_STA_BRTC
# 126860     3    3.1     3.1.2  SH_STA_BRTC
# 126861     3    3.1     3.1.2  SH_STA_BRTC
# 126862     3    3.1     3.1.2  SH_STA_BRTC
# 126863     3    3.1     3.1.2  SH_STA_BRTC
# 126864     3    3.1     3.1.2  SH_STA_BRTC
# 126865     3    3.1     3.1.2  SH_STA_BRTC
# 126866     3    3.1     3.1.2  SH_STA_BRTC
# 126867     3    3.1     3.1.2  SH_STA_BRTC
# 126868     3    3.1     3.1.2  SH_STA_BRTC
# ...

# %%
goal4 = data[data['Goal']==4]
goal4
# Out:
#         Goal Target Indicator   SeriesCode  \
# 311367     4    4.1     4.1.1  SE_MAT_PROF
# 311368     4    4.1     4.1.1  SE_MAT_PROF
# 311369     4    4.1     4.1.1  SE_MAT_PROF
# 311370     4    4.1     4.1.1  SE_MAT_PROF
# 311371     4    4.1     4.1.1  SE_MAT_PROF
# 311372     4    4.1     4.1.1  SE_MAT_PROF
# 311373     4    4.1     4.1.1  SE_MAT_PROF
# 311374     4    4.1     4.1.1  SE_MAT_PROF
# 311375     4    4.1     4.1.1  SE_MAT_PROF
# 311376     4    4.1     4.1.1  SE_MAT_PROF
# 311377     4    4.1     4.1.1  SE_MAT_PROF
# 311378     4    4.1     4.1.1  SE_MAT_PROF
# 311379     4    4.1     4.1.1  SE_MAT_PROF
# 311380     4    4.1     4.1.1  SE_MAT_PROF
# 311381     4    4.1     4.1.1  SE_MAT_PROF
# 311382     4    4.1     4.1.1  SE_MAT_PROF
# 311383     4    4.1     4.1.1  SE_MAT_PROF
# 311384     4    4.1     4.1.1  SE_MAT_PROF
# 311385     4    4.1     4.1.1  SE_MAT_PROF
# 311386     4    4.1     4.1.1  SE_MAT_PROF
# 311387     4    4.1     4.1.1  SE_MAT_PROF
# ...

# %%
goal5 = data[data['Goal']==5]
goal5

goal6 = data[data['Goal']==6]
goal6

goal7 = data[data['Goal']==7]
goal7

goal8 = data[data['Goal']==8]
goal8

goal9 = data[data['Goal']==9]
goal9

goal10 = data[data['Goal']==10]
goal10

goal11 = data[data['Goal']==11]
goal11

goal12 = data[data['Goal']==12]
goal12

goal13 = data[data['Goal']==13]
goal13

goal14 = data[data['Goal']==14]
goal14

goal14 = data[data['Goal']==14]
goal14

goal14 = data[data['Goal']==14]
goal14

goal15 = data[data['Goal']==15]
goal15

goal16 = data[data['Goal']==16]
goal16

goal17 = data[data['Goal']==15]
goal17
# Out:
#         Goal Target Indicator   SeriesCode  \
# 357673     5    5.2     5.2.1  VC_VAW_MARR
# 357674     5    5.2     5.2.1  VC_VAW_MARR
# 357675     5    5.2     5.2.1  VC_VAW_MARR
# 357676     5    5.2     5.2.1  VC_VAW_MARR
# 357677     5    5.2     5.2.1  VC_VAW_MARR
# 357678     5    5.2     5.2.1  VC_VAW_MARR
# 357679     5    5.2     5.2.1  VC_VAW_MARR
# 357680     5    5.2     5.2.1  VC_VAW_MARR
# 357681     5    5.2     5.2.1  VC_VAW_MARR
# 357682     5    5.2     5.2.1  VC_VAW_MARR
# 357683     5    5.2     5.2.1  VC_VAW_MARR
# 357684     5    5.2     5.2.1  VC_VAW_MARR
# 357685     5    5.2     5.2.1  VC_VAW_MARR
# 357686     5    5.2     5.2.1  VC_VAW_MARR
# 357687     5    5.2     5.2.1  VC_VAW_MARR
# 357688     5    5.2     5.2.1  VC_VAW_MARR
# 357689     5    5.2     5.2.1  VC_VAW_MARR
# 357690     5    5.2     5.2.1  VC_VAW_MARR
# 357691     5    5.2     5.2.1  VC_VAW_MARR
# 357692     5    5.2     5.2.1  VC_VAW_MARR
# 357693     5    5.2     5.2.1  VC_VAW_MARR
# ...

# %%
# write to csv
goal1.to_csv('goal1.csv')
goal2.to_csv('goal2.csv')
goal3.to_csv('goal3.csv')
goal4.to_csv('goal4.csv')
goal5.to_csv('goal5.csv')
goal6.to_csv('goal6.csv')
goal7.to_csv('goal7.csv')
goal8.to_csv('goal8.csv')
goal9.to_csv('goal9.csv')
goal10.to_csv('goal10.csv')
goal11.to_csv('goal11.csv')
goal12.to_csv('goal12.csv')
goal13.to_csv('goal13.csv')
goal14.to_csv('goal14.csv')
goal15.to_csv('goal15.csv')
goal16.to_csv('goal16.csv')
goal17.to_csv('goal17.csv')

# %%
goal['[Reporting Type]'].value_counts()
# Out:
# G    1122608
# Name: [Reporting Type], dtype: int64

# %%
goal1.isnull().sum()
# Out:
# Goal                                       0
# Target                                     0
# Indicator                                  0
# SeriesCode                                 0
# SeriesDescription                          0
# GeoAreaCode                                0
# GeoAreaName                                0
# TimePeriod                                 0
# Value                                      0
# Time_Detail                              107
# Source                                     0
# FootNote                               11677
# Nature                                  1420
# Units                                      0
# [Age]                                  55297
# [Bounds]                               64468
# [Cities]                               64468
# [Disability status]                    64468
# [Education level]                      64468
# [Freq]                                 64468
# [Hazard type]                          32058
# ...

# %%
goal1['[Sex]'].value_counts()
# Out:
# BOTHSEX    4640
# FEMALE     3371
# MALE       3298
# Name: [Sex], dtype: int64

# %%
# Out:
# 15+      3057
# 15-24    3057
# 25+      3057
# Name: [Age], dtype: int64

# %%
goal1['FootNote'].value_counts()
# Out:
# Disclaimer: the data being submitted by UNISDR has been extracted from two sources: (a) the Sendai Framework Monitoring System as provided by designated national focal points; and (b) Desinventar disaster loss databases. Some of the data has not finalized an official validation process and may be subject to revision at a later date.”                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
#This is a function to count the percentage of null values through mathematical calculations 
def nulls(df):
    #fig,ax=plt.figsize(18,12)
    nulls = pd.DataFrame(round(df.isnull().sum()/len(df.index)*100,2),columns=['null_percent'])
    #sns.barplot(x='index',y='null_percent',data=nulls.reset_index())
    return nulls[nulls['null_percent']!=0.00].sort_values('null_percent',ascending=False)

# %%
goal1[]

# %%
goal1['FootNote'].value_counts()

# %%
goal1['FootNote'].value_counts()

# %%
goal1.columns
# Out:
# Index(['Goal', 'Target', 'Indicator', 'SeriesCode', 'SeriesDescription',
#        'GeoAreaCode', 'GeoAreaName', 'TimePeriod', 'Value', 'Time_Detail',
#        'Source', 'FootNote', 'Nature', 'Units', '[Age]', '[Bounds]',
#        '[Cities]', '[Disability status]', '[Education level]', '[Freq]',
#        '[Hazard type]', '[IHR Capacity]', '[Level/Status]', '[Location]',
#        '[Migratory status]', '[Mode of transportation]',
#        '[Name of international institution]',
#        '[Name of non-communicable disease]', '[Quantile]', '[Reporting Type]',
#        '[Sex]', '[Tariff regime (status)]', '[Type of mobile technology]',
#        '[Type of occupation]', '[Type of product]', '[Type of skill]',
#        '[Type of speed]'],
#       dtype='object')

# %%
#keep necessary
goal1new = goal1[['Goal', 'Target', 'Indicator', 'SeriesCode', 'SeriesDescription',
       'GeoAreaCode', 'GeoAreaName', 'TimePeriod', 'Value', 'Time_Detail',
       'Source', 'FootNote', 'Nature', 'Units', '[Age]','[Sex]']]
goal1new.head().T
# Out:
#                                                                    0  \
# Goal                                                               1
# Target                                                           1.1
# Indicator                                                      1.1.1
# SeriesCode                                               SI_POV_DAY1
# SeriesDescription  Proportion of population below international p...
# GeoAreaCode                                                        1
# GeoAreaName                                                    World
# TimePeriod                                                      2002
# Value                                                           25.6
# Time_Detail                                                     2002
# Source             World Bank, Development Research Group. Data a...
# FootNote                                            World aggregate.
# Nature                                                             G
# ...

# %%
goal1new['SeriesDescription'].value_counts()
# Out:
# Employed population below international poverty line, by sex and age (%)                                                                                          9171
# Number damaged dwellings attributed to disasters, by hazard type (number)                                                                                         6482
# Number destroyed dwellings attributed to disasters, by hazard type (number)                                                                                       6482
# Number of deaths and missing persons attributed to disasters, by hazard type (number)                                                                             6482
# Direct agriculture loss attributed to disasters, by hazard type (millions of current United States dollars)                                                       6482
# ...

# %%
goal2.SeriesDescription.value_counts()
# Out:
# Agriculture orientation index for government expenditures                                                                         5202
# Agriculture value added share of GDP (%)                                                                                          5202
# Agriculture share of Government Expenditure (%)                                                                                   5202
# Prevalence of undernourishment (%)                                                                                                5045
# Number of undernourish people (millions)                                                                                          5045
# Proportion of local breeds classified as known being at risk (%)                                                                  4018
# Local breeds classified as being at unknown level of risk of extinction (number)                                                  4018
# ...

# %%
goal_1 = pd.read_csv('D:\\UTD\\2019SP\\IAC final\\goal1new.csv')
# Out:
#    Unnamed: 0  Goal  Target Indicator   SeriesCode  \
# 0           0     1     1.1     1.1.1  SI_POV_DAY1
# 1           1     1     1.1     1.1.1  SI_POV_DAY1
# 2           2     1     1.1     1.1.1  SI_POV_DAY1
# 3           3     1     1.1     1.1.1  SI_POV_DAY1
# 4           4     1     1.1     1.1.1  SI_POV_DAY1
#
#                                    SeriesDescription  GeoAreaCode GeoAreaName  \
# 0  Proportion of population below international p...            1       World
# 1  Proportion of population below international p...            1       World
# 2  Proportion of population below international p...            1       World
# 3  Proportion of population below international p...            1       World
# 4  Proportion of population below international p...            1       World
#
#    TimePeriod  Value  Time_Detail  \
# 0        2002   25.6         2002
# 1        2005   20.7         2005
# 2        2008   18.1         2008
# 3        2010   15.7         2010
# ...

# %%
goal_1.head().T
# Out:
#                                                                    0  \
# Unnamed: 0                                                         0
# Goal                                                               1
# Target                                                           1.1
# Indicator                                                      1.1.1
# SeriesCode                                               SI_POV_DAY1
# SeriesDescription  Proportion of population below international p...
# GeoAreaCode                                                        1
# GeoAreaName                                                    World
# TimePeriod                                                      2002
# Value                                                           25.6
# Time_Detail                                                     2002
# Source             World Bank, Development Research Group. Data a...
# Nature                                                             G
# ...

# %%
goal1_r = goal_1[['GeoAreaName','Value']].groupby(['GeoAreaName']).mean().sort_values('Value').reset_index()
goal1_r
# Out:
#                                            GeoAreaName      Value
# 0                                              Germany   0.000000
# 1                                               Cyprus   0.000000
# 2                                               France   0.000000
# 3                                              Finland   0.000000
# 4                                              Czechia   0.000000
# 5                                             Slovenia   0.000000
# 6                                          Switzerland   0.000000
# 7                                              Lebanon   0.000000
# 8                                          Netherlands   0.033333
# 9                                           Luxembourg   0.038462
# 10                                             Iceland   0.066667
# 11                                              Norway   0.107692
# 12                                             Belgium   0.123077
# ...

# %%
goal_2[['GeoAreaName','Value']].groupby(['GeoAreaName']).mean().sort_values('Value')

# %%
goal_1[]

# %%
data_new = data.copy()
data_new['Value'] =data_new['Value'].apply(pd.to_numeric, errors = 'ceorce')
data_new.describe()
# Out:
#                Goal   GeoAreaCode    TimePeriod         Value  [Quantile]
# count  1.139884e+06  1.139884e+06  1.139884e+06  1.116669e+06         0.0
# mean   8.064341e+00  4.013854e+02  2.009302e+03  2.272742e+09         NaN
# std    4.538784e+00  2.628177e+02  5.091410e+00  1.340603e+12         NaN
# min    1.000000e+00  1.000000e+00  2.000000e+03 -1.595867e+04         NaN
# 25%    3.000000e+00  1.700000e+02  2.005000e+03  3.296300e-01         NaN
# 50%    8.000000e+00  4.040000e+02  2.010000e+03  6.800000e+00         NaN
# 75%    1.200000e+01  6.200000e+02  2.014000e+03  9.014165e+01         NaN
# max    1.700000e+01  9.190000e+02  2.019000e+03  1.000000e+15         NaN

# %%
data_output = data_new[['GeoAreaName','Value']].groupby('GeoAreaName').mean()
data_output
# Out:
#                                                            Value
# GeoAreaName
# Afghanistan                                         5.335481e+06
# Africa                                              2.152397e+08
# Albania                                             2.377804e+06
# Algeria                                             8.185162e+07
# American Samoa                                      8.151807e+01
# Americas                                            6.409762e+08
# Andorra                                             4.789966e+02
# Angola                                              1.620439e+07
# Anguilla                                            1.146841e+02
# Antigua and Barbuda                                 8.924203e+05
# Argentina                                           1.325517e+08
# Armenia                                             1.348763e+06
# Aruba                                               1.629956e+05
# ...

# %%
data_output.to_csv('data_output.csv')

# %%
goal2_new = pd.read_csv('D:\\UTD\\2019SP\\IAC final\\goal2_new.csv')
goal2_new.head().T
# Out:
#                                                                                      0  \
# Unnamed: 0                                                                       64468
# Goal                                                                                 2
# Target                                                                             2.1
# Indicator                                                                        2.1.2
# SeriesCode                                                               AG_PRD_FIESSI
# SeriesDescription                    Prevalence of severe food insecurity in the ad...
# GeoAreaCode                                                                          1
# GeoAreaName                                                                      World
# TimePeriod                                                                        2015
# Value                                                                                9
# ...

# %%
goal2_new[['GeoAreaName','Value']].groupby(['GeoAreaName']).mean().sort_values('Value')
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-53-6e75af5a3af3> in <module>
# ----> 1 goal2_new[['GeoAreaName','Value']].groupby(['GeoAreaName']).mean().sort_values('Value')
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1130         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1131         try:
# -> 1132             return self._cython_agg_general('mean', **kwargs)
#    1133         except GroupByError:
#    1134             raise
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#      68                             min_count=-1):
#      69         new_items, new_blocks = self._cython_agg_blocks(
# ---> 70             how, alt=alt, numeric_only=numeric_only, min_count=min_count)
# ...
